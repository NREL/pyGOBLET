# %% [markdown]
# <h1><center> Tutorial 5: Pyomo Integration </center></h1>
#
# ---
#
# This tutorial shows how to access pyGOLD's standard benchmark problems as Pyomo models. pyGOLD can convert its optimization problems into Pyomo's modeling format, allowing the testing of algorithms that rely on the Pyomo framework. However, at this time pyGOLD does not support automated benchmarking of Pyomo-based optimization algorithms.
#
# ### Installation Requirements
#
# To run the example code in this notebook, you'll need Pyomo and the solvers ipopt and glpk. Accessing the problems as Pyomo models only requires the Pyomo package. These dependencies are not required for any other feature of the pyGOLD library.
#
# ```bash
# conda install -c conda-forge pyomo ipopt glpk
# ```
#
# ## Part 1: The ``.as_pyomo_model()`` Method
# ---
#
# Problems from pyGOLD's standard problems module can be automatically converted to Pyomo models using the problem's `.as_pyomo_model()` method. This is not a static method. The problem class must be instanciated with desired dimension before this method can be called. For example:

# %%
import numpy as np
from pyomo.environ import SolverFactory
import pygold

# Select a problem
problem = pygold.problems.standard.Ackley(3)

# Conver t the problem to a Pyomo model
pyomo_model = problem.as_pyomo_model()

type(pyomo_model)
# Out:
# pyomo.core.base.PyomoModel.ConcreteModel

# %% [markdown]
# The ``.as_pyomo_model()`` method handles all parts of constructing the problem as a Pyomo ConcreteModel including setting variable bounds and adding constraint functions, if present. The variable values are initialized to the middle of the bounds.

# %% [markdown]
# ## Part 2: Example
# ---

# %%
# Choose benchmark problems to use
problems = pygold.get_standard_problems("All")

# Choose pyomo solver to use
solver = SolverFactory('gdpopt')

# Solve each problem with the solver
for problem in problems:
    print(f"\nOptimizing: {problem.__name__}")

    # If problem is n-dimensional, initialize it in 2D
    # Problems must have a specific dimension to be accessed as a pyomo model
    if isinstance(problem.DIM, tuple):
        initialized = problem(2)
    else:
        initialized = problem(problem.DIM)

    # Get the pyomo model
    model = initialized.as_pyomo_model()

    # Solve the problem
    try:
        result = solver.solve(model, algorithm='LOA', tee=False, nlp_solver='ipopt', mip_solver='glpk')
    except Exception as e:
        print(f"Solver failed with error: {e}")
        continue

    # Take the optimal solution
    x_opt = np.array([model.x[i].value for i in range(initialized._ndims)])

    # Output the results
    print(f"Calculated Optimal x: {x_opt}")
    print(f"True Optimal x: {initialized.argmin()}")
# Out:
# Optimizing: Rosenbrock
# Calculated Optimal x: [1.00000001 1.00000002]
# True Optimal x: [[1.0, 1.0]]
#
# Optimizing: Rothyp
# Calculated Optimal x: [3.06640151e-25 3.27680000e-03]
# True Optimal x: [[0.0, 0.0]]
#
# Optimizing: HolderTable
# Calculated Optimal x: [1.26262726e+00 2.50855166e-23]
# True Optimal x: [[8.05502, 9.66459], [-8.05502, -9.66459], [8.05502, -9.66459], [-8.05502, 9.66459]]
#
# Optimizing: Colville
# Calculated Optimal x: [1. 1. 1. 1.]
# True Optimal x: [[1, 1, 1, 1]]
#
# Optimizing: Matyas
# Calculated Optimal x: [1.74706459e-18 1.74706459e-18]
# True Optimal x: [[0, 0]]
#
# Optimizing: Schaffer4
# Calculated Optimal x: [-1.53483098e-10  2.80241459e+00]
# True Optimal x: [[0.0, 1.253115], [0.0, -1.253115], [1.253115, 0.0], [-1.253115, 0.0]]
#
# Optimizing: Perm
# Calculated Optimal x: [1.         1.99998185]
# True Optimal x: [[1, 2]]
#
# Optimizing: DixonPrice
# Calculated Optimal x: [1.         0.70710678]
# True Optimal x: [[1.0, 0.7071067811865476]]
#
# Optimizing: Perm0
# Calculated Optimal x: [0.47826087 0.97826087]
# True Optimal x: [[1.0, 0.5]]
#
# Optimizing: RosenSuzuki
# Calculated Optimal x: [ 1.74231012e-09  1.00000000e+00  2.00000001e+00 -1.00000001e+00]
# True Optimal x: [[0, 1, 2, -1]]
#
# Optimizing: Griewank
# Calculated Optimal x: [1.34376872e-25 2.34997354e-26]
# True Optimal x: [[0.0, 0.0]]
#
# Optimizing: Branin
# Calculated Optimal x: [3.14159265 2.275     ]
# True Optimal x: [[-3.141592653589793, 12.275], [3.141592653589793, 2.275], [9.42478, 2.475]]
#
# Optimizing: Booth
# Calculated Optimal x: [1. 3.]
# True Optimal x: [[1, 3]]
#
# Optimizing: Schaffer2
# Calculated Optimal x: [2.19609857e-18 2.19534419e-18]
# True Optimal x: [[0.0, 0.0]]
#
# Optimizing: Hartmann6D
# Calculated Optimal x: [0.20168951 0.15001069 0.47687397 0.27533243 0.31165162 0.65730053]
# True Optimal x: [[0.20169, 0.150011, 0.476874, 0.275332, 0.311652, 0.6573]]
#
# Optimizing: Camel6
# Calculated Optimal x: [-0.08984201  0.7126564 ]
# True Optimal x: [[0.08984201368301331, -0.7126564032704135], [-0.08984201368301331, 0.7126564032704135]]
#
# Optimizing: Bohachevsky3
# Calculated Optimal x: [ 2.50696396e-25 -1.78303704e-25]
# True Optimal x: [[0.0, 0.0]]
#
# Optimizing: Bird
# WARNING (W1002): Setting Var 'x[0]' to a numeric value `-12` outside the
# bounds (-6, None).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# Calculated Optimal x: [-2.93603601 -0.44587523]
# True Optimal x: [[4.70104, 3.15294]]
#
# Optimizing: Bukin6
# Solver failed with error: Cannot load a SolverResults object with bad status: error
#
# Optimizing: GramacyLee
# Calculated Optimal x: [1.54728833]
# True Optimal x: [0.548563444114526]
#
# Optimizing: Beale
# Calculated Optimal x: [3.  0.5]
# True Optimal x: [[3, 0.5]]
#
# Optimizing: Trid
# Calculated Optimal x: [2. 2.]
# True Optimal x: [[2, 2]]
#
# Optimizing: Rastrigin
# Calculated Optimal x: [1.46521422e-26 1.46521422e-26]
# True Optimal x: [[0.0, 0.0]]
#
# Optimizing: Hartmann4D
# Calculated Optimal x: [0.40175428 0.82908208 0.77198938 0.55620352]
# True Optimal x: None
#
# Optimizing: Camel3
# Calculated Optimal x: [-4.15573797e-24  2.37068738e-24]
# True Optimal x: [[0.0, 0.0]]
#
# Optimizing: Powell
# Calculated Optimal x: [0.5 0.5]
# True Optimal x: [[0.0, 0.0]]
#
# Optimizing: Bohachevsky2
# Calculated Optimal x: [ 2.16920906e-26 -1.17403330e-26]
# True Optimal x: [[0.0, 0.0]]
#
# Optimizing: RosenbrockConstrained
# Calculated Optimal x: [0.78641515 0.61769831]
# True Optimal x: [[0.7864, 0.6177]]
#
# Optimizing: EggHolder
# Calculated Optimal x: [ 8.45693447 15.65091813]
# True Optimal x: [[512, 404.2319]]
#
# Optimizing: Ackley
# WARNING: Loading a SolverResults object with a warning status into
# model.name="unknown";
#     - termination condition: maxIterations
#     - message from solver: Ipopt 3.14.17\x3a Maximum Number of Iterations
#       Exceeded.
# Calculated Optimal x: [0.00138827 0.00138661]
# True Optimal x: [[0.0, 0.0]]
#
# Optimizing: Michalewicz
# Calculated Optimal x: [2.20290552 1.57079633]
# True Optimal x: [[2.202906, 1.570796]]
#
# Optimizing: SumSq
# Calculated Optimal x: [-6.37783634e-24 -3.03852494e-24]
# True Optimal x: [[0.0, 0.0]]
#
# Optimizing: Levy13
# Calculated Optimal x: [0.01127787 0.00793715]
# True Optimal x: [[1.0, 1.0]]
#
# Optimizing: Hartmann3D
# Calculated Optimal x: [0.1145889  0.55564889 0.85254698]
# True Optimal x: [[0.114614, 0.555649, 0.852547]]
#
# Optimizing: Zakharov
# Calculated Optimal x: [1.86648601e-10 9.33195866e-11]
# True Optimal x: [[0.0, 0.0]]
#
# Optimizing: Bohachevsky1
# Calculated Optimal x: [-3.22257702e-26  6.25253798e-27]
# True Optimal x: [[0.0, 0.0]]
#
# Optimizing: StyblinskiTang
# Calculated Optimal x: [-2.90353403 -2.90353403]
# True Optimal x: [[-2.903534, -2.903534]]
#
# Optimizing: DropWave
# Calculated Optimal x: [-6.53886440e-26 -3.64561842e-26]
# True Optimal x: [[0.0, 0.0]]
#
# Optimizing: Easom
# Calculated Optimal x: [1.30499551 1.30499551]
# True Optimal x: [[3.141592653589793, 3.141592653589793]]
#
# Optimizing: SumPow
# Calculated Optimal x: [1.30495722e-16 1.84236529e-05]
# True Optimal x: [[0.0, 0.0]]
#
# Optimizing: Levy
# Calculated Optimal x: [1. 1.]
# True Optimal x: [[1.0, 1.0]]
#
# Optimizing: GoldsteinPrice
# Calculated Optimal x: [-0.6 -0.4]
# True Optimal x: [[0, -1]]
#
# Optimizing: PowerSum
# Calculated Optimal x: [2.30100798 2.30100798 2.30100798 2.30100798]
# True Optimal x: [[1, 2, 2, 3]]
#
# Optimizing: Shubert
# Calculated Optimal x: [ 0.33424391 -0.19538575]
# True Optimal x: [[-7.0835, 4.858], [-7.0835, -7.7083], [-1.4251, -7.0835], [5.4828, 4.858], [-1.4251, -0.8003], [4.858, 5.4828], [-7.7083, -7.0835], [-7.0835, -1.4251], [-7.7083, -0.8003], [-7.7083, 5.4828], [-0.8003, -7.7083], [-0.8003, -1.4251], [-0.8003, 4.858], [-1.4251, 5.4828], [5.4828, -7.7083], [4.858, -7.0835], [5.4828, -1.4251], [4.858, -0.8003]]
#
# Optimizing: Shekel
# Calculated Optimal x: [4.00074687 3.99950948 4.00074687 3.99950948]
# True Optimal x: [[4, 4, 4, 4]]
#
# Optimizing: CrossInTray
# Calculated Optimal x: [1.34940662 1.34940662]
# True Optimal x: [[1.349406608602084, -1.349406608602084], [1.349406608602084, 1.349406608602084], [-1.349406608602084, 1.349406608602084], [-1.349406608602084, -1.349406608602084]]
#
# Optimizing: Dejong5
# Calculated Optimal x: [0.02804964 0.02805044]
# True Optimal x: None
#
# Optimizing: Sphere
# Calculated Optimal x: [-1.55833326e-24 -1.55833326e-24]
# True Optimal x: [[0.0, 0.0]]
#
# Optimizing: Langermann
# Calculated Optimal x: [4.94227083 5.46957313]
# True Optimal x: [[2.002992, 1.006096]]
#
# Optimizing: Forrester
# Calculated Optimal x: [0.14258919]
# True Optimal x: [[0.75725]]
#
# Optimizing: McCormick
# Calculated Optimal x: [-0.54719755 -1.54719755]
# True Optimal x: [[-0.5471975602214493, -1.547197559268372]]
#
# Optimizing: Schwefel
# Calculated Optimal x: [5.2391993 5.2391993]
# True Optimal x: [[420.968746, 420.968746]]

# %% [markdown]
# ## Summary
#
# You've now seen how to convert pyGOLD problems to Pyomo models using `.as_pyomo_model()`.
#
# Next: **Example 1** will demonstrate a complete benchmarking workflow.
